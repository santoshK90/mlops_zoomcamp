# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/ubuntu/mlops_zoomcamp/06-best_practices/output

# %%
year=2022
month=1
input_path = f'/home/ubuntu/mlops_zoomcamp/06-best_practices/test/2022-01.parquet'
input = pd.read_parquet(input_path)
out_path= '2022-01.parquet'
input.to_parquet(
    out_path,
    engine='pyarrow',
    compression=None,
    index=False
)

# %%
import pandas as pd
df_input = pd.read_parquet("2022-01.parquet")
df_input.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# 5         1  2022-01-01 00:40:15   2022-01-01 01:09:48              1.0
# 6         2  2022-01-01 00:20:50   2022-01-01 00:34:58              1.0
# 7         2  2022-01-01 00:13:04   2022-01-01 00:22:45              1.0
# 8         2  2022-01-01 00:30:02   2022-01-01 00:44:49              1.0
# 9         2  2022-01-01 00:48:52   2022-01-01 00:53:28              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.80         1.0                  N           142           236
# ...

# %%
year=2022
month=1
input_file = f's3://nyc-duration/in/{year:04d}-{month:02d}.parquet'

# %%
options = {
    'client_kwargs': {
        'endpoint_url': "http://localhost:4566"
    }
}


df_input.to_parquet(
    input_file,
    engine='pyarrow',
    compression=None,
    index=False,
    storage_options=options
)

# %%
# !ls -s
# Out:
# total 83452
# 63656 2022-01.parquet  19792 yellow_tripdata_2022-02.parquet
#     4 save_file.ipynb
